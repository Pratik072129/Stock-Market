# %%
# prompt:  Basic Plots

import matplotlib.pyplot as plt
import seaborn as sns

# Example: Plotting a histogram of a numerical column
# Replace 'Close' with the actual name of a numerical column in your dataset
plt.figure(figsize=(10, 6))
sns.histplot(df['Close'], kde=True)
plt.title('Distribution of Closing Prices')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.show()

# Example: Plotting a scatter plot between two numerical columns
# Replace 'Close' and 'Volume' with actual numerical column names
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Close'], y=df['Volume'])
plt.title('Closing Price vs. Volume')
plt.xlabel('Close Price')
plt.ylabel('Volume')
plt.show()

# Example: Plotting a box plot of a numerical column
# Replace 'Open' with the actual name of a numerical column
plt.figure(figsize=(10, 6))
sns.boxplot(y=df['Open'])
plt.title('Box Plot of Opening Prices')
plt.ylabel('Open Price')
plt.show()
