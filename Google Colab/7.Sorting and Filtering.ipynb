# %%
# prompt: Sorting and Filtering

# Sorting data by a specific column (e.g., 'Close' in ascending order)
df_sorted_close_asc = df.sort_values(by='Close', ascending=True)
print("\nData sorted by 'Close' price (ascending):")
print(df_sorted_close_asc.head())

# Sorting data by a specific column (e.g., 'Volume' in descending order)
df_sorted_volume_desc = df.sort_values(by='Volume', ascending=False)
print("\nData sorted by 'Volume' (descending):")
print(df_sorted_volume_desc.head())

# Sorting by multiple columns (e.g., 'Index' then 'Date')
if 'Index' in df.columns and 'Date' in df.columns:
    df_sorted_multi = df.sort_values(by=['Index', 'Date'], ascending=[True, True])
    print("\nData sorted by 'Index' then 'Date':")
    print(df_sorted_multi.head())
else:
    print("\n'Index' or 'Date' column not found. Cannot sort by multiple columns.")

print("\nSorting examples complete.")

# Filtering data based on a condition (e.g., rows where 'Close' is greater than 30000)
df_filtered_close = df[df['Close'] > 30000]
print("\nData filtered where 'Close' > 30000:")
print(df_filtered_close.head())

# Filtering data based on multiple conditions (e.g., 'Volume' > 1000000 and 'High' < 40000)
df_filtered_multi = df[(df['Volume'] > 1000000) & (df['High'] < 40000)]
print("\nData filtered where 'Volume' > 1,000,000 and 'High' < 40,000:")
print(df_filtered_multi.head())

# Filtering data based on a list of values (e.g., rows where 'Index' is in a specific list)
if 'Index' in df.columns:
    index_list = ['^GSPC', '^DJI', '^IXIC']
    df_filtered_index = df[df['Index'].isin(index_list)]
    print(f"\nData filtered where 'Index' is in {index_list}:")
    print(df_filtered_index.head())
else:
    print(f"\n'Index' column not found. Cannot filter by index list.")

print("\nFiltering examples complete.")
# Out:
# Data sorted by 'Close' price (ascending):
#       Index       Date       Open       High        Low      Close  Adj Close  \
# 14871  IXIC 1974-10-03  54.869999  54.869999  54.869999  54.869999  54.869999
# 14872  IXIC 1974-10-04  55.160000  55.160000  55.160000  55.160000  55.160000
# 14869  IXIC 1974-10-01  55.480000  55.480000  55.480000  55.480000  55.480000
# 14870  IXIC 1974-10-02  55.669998  55.669998  55.669998  55.669998  55.669998
# 14868  IXIC 1974-09-30  55.669998  55.669998  55.669998  55.669998  55.669998
#
#        Volume  Close_Pct_Change  Year
# 14871     0.0         -0.014370  1974
# 14872     0.0          0.005285  1974
# 14869     0.0         -0.003413  1974
# 14870     0.0          0.003425  1974
# 14868     0.0         -0.025385  1974
#
# Data sorted by 'Volume' (descending):
#         Index       Date         Open         High          Low        Close  \
# 51890  GSPTSE 2020-06-19  15638.09961  15638.09961  15436.90039  15474.20020
# ...
